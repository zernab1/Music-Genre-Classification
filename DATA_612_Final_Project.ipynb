# %%
import matplotlib.pyplot as plt
import numpy as np
import wave
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
import os
import pickle
import librosa as lr
import librosa.display
from glob import glob
import IPython
from IPython.display import Audio
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
import scipy.io.wavfile as wav
# from python_speech_features import mfcc, logfbank

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
file_path = '/content/Top_50_songs/'
audio_recordings = []

for filename in os.listdir(file_path):
  # os.path.join(file_path, filename)
  audio_recordings.append(filename)

# %%
audio_recordings
# Out:
# ['Kate-Bush-Running-Up-That-Hill.wav',
#  'QUEVEDO_BZRP_Music_Sessions_52_(getmp3.pro).wav',
#  'Glass_Animals_-_Heat_Waves_(getmp3.pro).wav',
#  'Post Malone - I Like You.wav',
#  'Doja_Cat_-_Woman_Lyrics_(getmp3.pro).wav',
#  'Tate_McRae_-_shes_all_i_wanna_be__.wav',
#  'Ed_Sheeran_-_Shivers_Lyrics_(getmp3.pro).wav',
#  'Justin_Bieber_-_Ghost_(getmp3.pro).wav',
#  'Kendrick_Lamar_-_Die_Hard_Lyrics_(getmp3.pro).wav',
#  'Megan_Thee_Stallion_Dua_Lipa_-_Swe_(getmp3.pro).wav',
#  'Harry_Styles_-_Late_Night_Talking__(getmp3.pro).wav',
#  'Doja_Cat_-_Vegas_Lyrics_(getmp3.pro).wav',
#  'Bad_Bunny_-_Ojitos_Lindos_Letra__(getmp3.pro).wav',
#  'Future_-_WAIT_FOR_U_Lyrics_ft_Dr_(getmp3.pro).wav',
#  'Elley_Duh_-_Middle_of_the_Night_L_(getmp3.pro).wav',
#  'Lil_Nas_X_-_THATS_WHAT_I_WANT_Lyri_(getmp3.pro).wav',
#  'Billie_Eilish_-_TV_Official_Lyric_(getmp3.pro).wav',
#  'Burna_Boy_-_Last_Last_Lyrics_(getmp3.pro).wav',
#  'KAROL_G_-_PROVENZA_(getmp3.pro).wav',
#  'Beyonc_-_BREAK_MY_SOUL_Lyrics_(getmp3.pro).wav',
#  'Joji_-_Glimpse_of_Us_(getmp3.pro).wav',
#  'OneRepublic_-_I_Aint_Worried_Lyri_(getmp3.pro).wav',
#  'Cardi_B_-_Hot_Shit_Lyrics_feat_K_(getmp3.pro).wav',
#  'Lost_Frequencies_Calum_Scott_-_Wh_(getmp3.pro).wav',
#  'Bad_Bunny_-_Me_Porto_Bonito_Letra_(getmp3.pro).wav',
#  'Charlie_Puth_-_Light_Switch_Lyrics_(getmp3.pro).wav',
#  'Calvin_Harris_Dua_Lipa_Young_Thug_(getmp3.pro).wav',
#  'Benson_Boone_-_In_the_Stars_Offic_(getmp3.pro).wav',
#  'Dove_Cameron_-_Boyfriend_Lyrics_(getmp3.pro).wav',
#  'Lizzo_-_About_Damn_Time_(getmp3.pro).wav',
#  'Jack_Harlow_-_First_Class_(getmp3.pro).wav',
#  'Mneskin_-_SUPERMODEL_Lyrics_(getmp3.pro).wav',
#  'The_Kid_LAROI_Justin_Bieber_-_Stay.wav',
#  'Shakira_Rauw_Alejandro_-_Te_Felici_(getmp3.pro).wav',
#  'James_Hype_Miggy_Dela_Rosa_-_Ferra_(getmp3.pro).wav',
#  'Drake_-_Massive_Lyrics_(getmp3.pro).wav',
#  'Elton_John_Dua_Lipa_-_Cold_Heart_(getmp3.pro).wav',
#  'Nicky_Youre_dazy_-_Sunroof_Lyrics_(getmp3.pro).wav',
#  'Stephen_Sanchez_-_Until_I_Found_You.wav',
#  'Marshmello_Khalid_-_Numb_Audio_(getmp3.pro).wav',
#  'Lady_Gaga_-_Hold_My_Hand_Lyrics__(getmp3.pro).wav',
#  'Camila_Cabello_-_Bam_Bam_Lyrics_f_(getmp3.pro).wav',
#  'Rosa_Linn_-_SNAP_Lyrics_(getmp3.pro).wav',
#  'Post_Malone_-_Cooped_Up_Lyrics_ft_(getmp3.pro).wav',
#  'Latto_-_Big_Energy_Lyrics_(getmp3.pro).wav',
#  'The_Kid_LAROI_-_Thousand_Miles_Lyr.wav',
#  'Steve_Lacy_-_Bad_Habit_.wav',
#  'Charlie_Puth_-_Left_And_Right_Lyri_(getmp3.pro).wav',
#  'Harry Styles-As It Was.wav',
#  'Drake_-_Jimmy_Cooks_Lyrics_Ft_2_(getmp3.pro).wav']

# %%
# data_all = []

for audio in glob(r'/content/Top_50_songs/**/*.wav', recursive=True):
     (rate, sig) = wav.read(audio)
    #  data, sr = librosa.load(audio)
    #  data_all.append(data)
# print(type(data), type(sr))

# %%
IPython.display.Audio(data, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
