# %%
pip install python-speech-features
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for python-speech-features: filename=python_speech_features-0.6-py3-none-any.whl size=5888 sha256=6573399699f1091de551c88f101939c691bbd26d26d338faa2b0d117ce94d279
#   Stored in directory: /root/.cache/pip/wheels/b0/0e/94/28cd6afa3cd5998a63eef99fe31777acd7d758f59cf24839eb
# Successfully built python-speech-features
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import wave
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
import os
import pickle
import librosa as lr
import librosa.display
from glob import glob
import IPython
from IPython.display import Audio
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
import scipy.io.wavfile as wav
from python_speech_features import mfcc, logfbank

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
file_path = '/content/gdrive/MyDrive/Top_50_songs/'
audio_recordings = []

for filename in os.listdir(file_path):
  # os.path.join(file_path, filename)
  audio_recordings.append(filename)

# %%
audio_recordings
# Out:
# ['Kate-Bush-Running-Up-That-Hill.wav',
#  'QUEVEDO_BZRP_Music_Sessions_52_(getmp3.pro).wav',
#  'Glass_Animals_-_Heat_Waves_(getmp3.pro).wav',
#  'Post Malone - I Like You.wav',
#  'Doja_Cat_-_Woman_Lyrics_(getmp3.pro).wav',
#  'Tate_McRae_-_shes_all_i_wanna_be__.wav',
#  'Ed_Sheeran_-_Shivers_Lyrics_(getmp3.pro).wav',
#  'Justin_Bieber_-_Ghost_(getmp3.pro).wav',
#  'Kendrick_Lamar_-_Die_Hard_Lyrics_(getmp3.pro).wav',
#  'Megan_Thee_Stallion_Dua_Lipa_-_Swe_(getmp3.pro).wav',
#  'Harry_Styles_-_Late_Night_Talking__(getmp3.pro).wav',
#  'Doja_Cat_-_Vegas_Lyrics_(getmp3.pro).wav',
#  'Bad_Bunny_-_Ojitos_Lindos_Letra__(getmp3.pro).wav',
#  'Future_-_WAIT_FOR_U_Lyrics_ft_Dr_(getmp3.pro).wav',
#  'Elley_Duh_-_Middle_of_the_Night_L_(getmp3.pro).wav',
#  'Lil_Nas_X_-_THATS_WHAT_I_WANT_Lyri_(getmp3.pro).wav',
#  'Billie_Eilish_-_TV_Official_Lyric_(getmp3.pro).wav',
#  'Burna_Boy_-_Last_Last_Lyrics_(getmp3.pro).wav',
#  'KAROL_G_-_PROVENZA_(getmp3.pro).wav',
# ...

# %%
data = []
sample_rate = 22050

for audio_name in glob(r'/content/gdrive/MyDrive/Top_50_songs/**/*.wav', recursive=True):
  audio, sr = librosa.load(audio_name, sr=sample_rate)
  data.append(audio)
print(type(audio))
# Out:
# <class 'numpy.ndarray'>

# %%
len(data)
# Out:
# 50

# %%
# playing the audios

IPython.display.Audio(data[0], rate=sample_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# plotting the raw wave files

plt.figure(figsize=(8,2))
librosa.display.waveplot(data[0])
plt.show()

# %%
data_mfcc = []
sample_rate = 22050

for audio_name in glob(r'/content/gdrive/MyDrive/Top_50_songs/**/*.wav', recursive=True):
  audio, sr = librosa.load(audio_name, sr=sample_rate)
  mfcc = librosa.feature.mfcc(y=audio, sr=sample_rate)
  data_mfcc.append(mfcc)
print(type(mfcc))
# Out:
# <class 'numpy.ndarray'>

# %%
mfcc.shape
# Out:
# (20, 1292)

# %%
np.shape(data_mfcc)
# Out:
# (50, 20, 1292)

# %%
df = pd.DataFrame(data_mfcc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-c64799af26be> in <module>()
# ----> 1 df = pd.DataFrame(data_mfcc)
#       2
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     715                         dtype=dtype,
#     716                         copy=copy,
# --> 717                         typ=manager,
#     718                     )
#     719             else:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     302         # by definition an array here
#     303         # the dtypes will be coerced to a single dtype
# --> 304         values = _prep_ndarray(values, copy=copy)
#     305
#     306     if dtype is not None and not is_dtype_equal(values.dtype, dtype):
#
# ...

# %%
# adding labels to the data

# %%
# lable encoding

# %%
# scaling the features

# %%
# deviding the data into train and test setz

# %%
# building the model
